# %% [markdown]
# # Pandas Built-in Data Visualization

# %%
import pandas as pd
import matplotlib as plt
import numpy as np

import seaborn as sns
# %matplotlib inline

# %%
df1 = pd.read_csv('df1', index_col = 0)
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist()

#histogram of all values in column A

# %%
df1['A'].hist(bins = 30)
#seaborn argument = bins

#histogram of all values in column A

# %%
import seaborn as sns
sns.set_style("whitegrid")

# %%
sns.set_style("dark")

# %%
df1['A'].hist(bins = 30)

# %%
df1['A'].plot(kind = 'hist', bins = 30)

#another method to call for histogram

# %%
sns.set_style("darkgrid")

# %%
df1['A'].plot.hist()

#direct method to call histogram

# %%
df2.plot.area()

#shows area of all columns within data

# %%
df2.plot.area(alpha=0.4)

#shows area of all columns within data
#alpha shows some tranparency

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.bar()

#takes index value as categorical 0-9 in rows, which is index from data

# %%
df2.plot.bar(stacked = True)

#takes index value as categorical 0-9 in rows, which is index from data

# %%
df1['A'].plot.hist()

# %%
df1['A'].plot.hist(bins = 50)

# %%
#line plots

df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.plot.line(x = df1.index, y = 'B')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-97-56e70c0c5a70> in <module>
# ----> 1 df1.plot.line(x = df1.index, y = 'B')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in line(self, x, y, **kwds)
#    3004             >>> lines = df.plot.line(x='pig', y='horse')
#    3005         """
# -> 3006         return self(kind='line', x=x, y=y, **kwds)
#    3007
#    3008     def bar(self, x=None, y=None, **kwds):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2940                           fontsize=fontsize, colormap=colormap, table=table,
# ...

# %%
df1.plot.line(y="B")
df1.plot(figsize=(10,10)) # chaingin plot size

# %%
plt.rcParams["figure.figsize"] = [10, 10]

#changing the size of plots globally for the entire book

# %%
df1.plot.line(y="B")

# %%
#adding matplotlib arguments
# can also add markers


df1.plot.line(y="B", figsize = (12,3), lw = 1)

# %%
df1.plot.scatter(x= 'A', y = 'B', c = 'C')

#three dimenstonal plot

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.plot.scatter(x= 'A', y = 'B', c = 'C', cmap = 'coolwarm')

#three dimenstonal plot

# %%
df1.plot.scatter(x= 'A', y = 'B', c = 'C', s =df1 ['C'] )

#sometime people want to show the data by size and not color 
# for that we can use argument s , size
# size will take a dataframe column
# and then we will have to multiply it with a number to make the size bigger

#also for size we can't pass c = some column
# c will be the argument with color (press shift tab) for more info

# %%
df1.plot.scatter(x= 'A', y = 'B', s = df1 ['C']*100 ,c= 'blue')

# %%
df2.plot.box()

# %%
#bivariant plot

df = pd.DataFrame(np.random.randn(1000,2), columns = ['a','b'])
df.plot.hexbin(x='a', y='b')

# %%
df.plot.hexbin(x='a', y='b', gridsize = 25, cmap='coolwarm')

# %%
df2['a'].plot.kde()

# %%
df2['a'].plot.density()

#kde and density are the same thing

# %%
#kde of all cols

df2.plot.density()
